# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# /usr/local/lib/python3.5/dist-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# 讀取唐詩檔案，將詩句取出
import json
poetry = []
with open('poet.tang.0.json' , 'r') as json_read:
    jf = json.load(json_read)
for i in range(0,len(jf)):
    line = jf[i]["paragraphs"]
    poetry.append(line)
    
with open('poet.tang.1000.json' , 'r') as json_read:
    jf = json.load(json_read)
for i in range(0,len(jf)):
    line = jf[i]["paragraphs"]
    poetry.append(line)
    
# 加上結尾記號
#for i in range(len(poetry)):
#    poetry[i] = list(poetry[i]) + ["E"]
    
print(len(poetry))
print(poetry[2])

# 把一首詩的句子結合在一行，去掉標點符號
data = []
for i in range(len(poetry)):
    line = "".join(poetry[i])
    line = line.replace("，","").replace("。","").replace("！","").replace("？","").replace("[","").replace("]","")
    line = line.replace("{","").replace("}","")
    data.append(line)
print(data[2])
# Out:
# 2000
# ['移步出詞林，停輿欣武宴。', '琱弓寫明月，駿馬疑流電。', '驚雁落虛弦，啼猿悲急箭。', '閱賞誠多美，於茲乃忘倦。']
# 移步出詞林停輿欣武宴琱弓寫明月駿馬疑流電驚雁落虛弦啼猿悲急箭閱賞誠多美於茲乃忘倦

# %%
# 將所有出現過的字建立字典，每個字元與標點符號都有對應數字
chars = []
for i in range(len(data)):
    chars_temp = sorted(list(set(data[i])))
    chars.extend(chars_temp)
chars = set(chars)
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
print(char_indices['無'])
# Out:
# total chars: 4281
# 3915

# %%
# 前五個字預測第六個字，每次前進兩個字
maxlen = 5
step = 2
sentences = []
next_chars = []
for lines in range(len(data)):
    for i in range(0, len(data[lines]) - maxlen, step):
        sentences.append(data[lines][i: i + maxlen])
        next_chars.append(data[lines][i + maxlen])
print('nb sequences:', len(sentences))
print(sentences[40])
print(next_chars[40])
# Out:
# nb sequences: 45572
# 武宴琱弓寫
# 明

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)

for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars), activation='softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# Build model...

# %%
def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)
        count = 0
        
        # sentence = 隨機選一段長度為5的句子
        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(35):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            
            if count%10 == 0:
                sys.stdout.write("，")
            elif count%5 == 0:
                sys.stdout.write("。")
            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
            count += 1
        sys.stdout.write("。")
        print()

# %%
text = ''.join(data)

# %%
print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback])
# Out:
# Epoch 1/30
# 45572/45572 [==============================] - 6s 135us/step - loss: 1.5114
#
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: "新賭得五陵"
# 新賭得五陵，日一年腸斷。斜隴頭笑年，不隴頭遠戰。盡不相通中，一人一生死。生長安憂一，來萬里誰莫。
# ----- diversity: 0.5
# ----- Generating with seed: "新賭得五陵"
# 新賭得五陵，日一年腸斷。斜夕初昔更，是初氣今日。都家火應須，入醉燒子百。過側玉宮門，門隨金無靜。
# ----- diversity: 1.0
# ----- Generating with seed: "新賭得五陵"
# 新賭得五陵，萋一堤豈鬯。舞贈殊鮮滋，謝臨了則帳。蜀繫報逢河，闕驅種西孤。開入叢少持，曾環渭表央。
# ----- diversity: 1.2
# ----- Generating with seed: "新賭得五陵"
# 新賭得五陵，推之屈流臺。屋白渚鄰愛，尋天在下秩。尺杖京罄危，靜功冬嗟歲。身雷悔嫌纓，土桃英昏尋。
# Epoch 2/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5278
#
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "顏豔名都綠"
# 顏豔名都綠，條城素寶無。爲無寶華香，聞死上宿江。南南望平日，日不此不見。人如知何名，上不歸見有。
# ----- diversity: 0.5
# ----- Generating with seed: "顏豔名都綠"
# 顏豔名都綠，條口素王度。驅道火沙來，飲馬出門門。不盡聞金石，枕清暗去行。浪水山願作，行行時是屋。
# ----- diversity: 1.0
# ----- Generating with seed: "顏豔名都綠"
# 顏豔名都綠，雲榮故飜持。尋遍齊直鐵，痕古戍顧幾。浩徒意恩實，窈宣噴蓮口。由鴦各倫凱，帝入父三光。
# ----- diversity: 1.2
# ----- Generating with seed: "顏豔名都綠"
# 顏豔名都綠，條北雖收笛。至南欲得眺，自恩變溢勤。胡萬了矣余，得即斜滴侍。畢點關長淮，好湖不嗁住。
# Epoch 3/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5096
#
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "天貺順時休"
# 天貺順時休，重重不重歸。論生得胡沙，得老金來養。秦德聲天聞，聞風關胡夜。愁光愁歸坐，夜使無人道。
# ----- diversity: 0.5
# ----- Generating with seed: "天貺順時休"
# 天貺順時休，相見上征垂。已月行人離，明胡樓行人。漢城臨王將，亂洛賢育開。同猨迥欲飛，飛薦家行行。
# ----- diversity: 1.0
# ----- Generating with seed: "天貺順時休"
# 天貺順時休，徵美人行帆。環空十漏狼，育流功傾錦。襄淒高衰望，咽下不破城。京酸棄平不，已聞建國掌。
# ----- diversity: 1.2
# ----- Generating with seed: "天貺順時休"
# 天貺順時休，致簾自翼那。朔眉急流焦，凱泰磧蒿藕。潭欵竹移雕，難母反塘坐。駿函甲笛葵，滅芙蛾才陳。
# Epoch 4/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5174
#
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: "禋聲明已備"
# 禋聲明已備，同萬影天聲。明月朝入四，五月月明南。風妾西家連，羅娥東羅惜。宮振紅歌來，入懸中上玄。
# ----- diversity: 0.5
# ----- Generating with seed: "禋聲明已備"
# 禋聲明已備，同屬影輕坐。有田宗尚衰，孤威少鞍春。萬集誰裳世，辭鳳迢當老。草用君飄豈，有棄臺飛入。
# ----- diversity: 1.0
# ----- Generating with seed: "禋聲明已備"
# 禋聲明已備，箱全昭以笛。截用白獻醉，忽還待執委。金鼓冥開嘗，繁想且蟬英。鴻求改陳輦，里稱逢流迢。
# ----- diversity: 1.2
# ----- Generating with seed: "禋聲明已備"
# 禋聲明已備，赴殺郎預鴦。願越堤朔條，磧綠南撤語。練容穀干人，還戟妍渭翡。焉壓張牛綺，笙霍暫越船。
# Epoch 5/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5218
#
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "征戰宿將今"
# 征戰宿將今，處老且清歌。聞吹使夜天，高明日出光。何處移生亦，日多春風綠。半中新嘶玉，暖散出雙落。
# ----- diversity: 0.5
# ----- Generating with seed: "征戰宿將今"
# 征戰宿將今，明邊攜多入。戰美人起聲，多易空落啼。想雲恨中愁，思人生死世。西營潔那知，青山邊如骨。
# ----- diversity: 1.0
# ----- Generating with seed: "征戰宿將今"
# 征戰宿將今，明獻嗟吏冷。燭烹宸背燭，受暉福陳荷。分意低頻堪，城祗閉亂浪。豐苔激寥紛，巖物類蟬須。
# ----- diversity: 1.2
# ----- Generating with seed: "征戰宿將今"
# 征戰宿將今，落荆李若前。失誰轉晚鳶，復客詞麗廟。兔湘星穀家，卻怨衢率破。彩受戶中張，定翁衢充能。
# Epoch 6/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4993
#
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "霞散紅抽思"
# 霞散紅抽思，雪泉金遠人。流寒入美人，迷觴玉落金。將爲白白日，與黃金淚別。離白落起花，花中春時暮。
# ----- diversity: 0.5
# ----- Generating with seed: "霞散紅抽思"
# 霞散紅抽思，雪泉淚思愁。歲心直回且，清且谷竹上。上鴻山之江，寒遙雪似家。花水雙宿陰，笑度問一看。
# ----- diversity: 1.0
# ----- Generating with seed: "霞散紅抽思"
# 霞散紅抽思，聽吳兵淺且。庭累花彰遺，幽集饗夢物。衛祗韶團間，閉縫覺聲咽。使定似更明，潺還辰兩行。
# ----- diversity: 1.2
# ----- Generating with seed: "霞散紅抽思"
# 霞散紅抽思，場母君已顏。團值我下鑒，輕兵干噴冰。細山膏讓涯，其順將繡危。父正談桃帳，春恨物上收。
# Epoch 7/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5099
#
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: "差碧岫聳蓮"
# 差碧岫聳蓮，蓮柔有中春。花樂樂無窮，日神生江歡。樂悲各有情，無雄分心惜。侵日行一去，將西看日明。
# ----- diversity: 0.5
# ----- Generating with seed: "差碧岫聳蓮"
# 差碧岫聳蓮，蓮叢有垂早。花醉還來沙，樓思人臣錦。一平沙渡鏡，章還傷思婦。因明劒浮歎，白萬方相憶。
# ----- diversity: 1.0
# ----- Generating with seed: "差碧岫聳蓮"
# 差碧岫聳蓮，射目君胡梁。何倫章蓬磧，移闌蕭實籠。射來營稱色，建間作去仙。粧弦悲從鳥，流雲銷紵宿。
# ----- diversity: 1.2
# ----- Generating with seed: "差碧岫聳蓮"
# 差碧岫聳蓮，綴棲音恥早。樂晚別烽疆，靜傳言蟬備。垂頓近摘堯，辛漠嬌自虹。往蔽敢波中，歡求銅祥載。
# Epoch 8/30
# 45572/45572 [==============================] - 6s 135us/step - loss: 1.4962
#
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "月南風興思"
# 月南風興思，人在竟落將。從黃金將軍，將朱顏將遠。胡沙淚愁見，親紅顏度滿。人地幾四得，宮愁君日妾。
# ----- diversity: 0.5
# ----- Generating with seed: "月南風興思"
# 月南風興思，人在作西山。客清風羞花，落黃葉王見。長宮入宮宮，生歡長樂成。不寶和無戎，衣戰不死長。
# ----- diversity: 1.0
# ----- Generating with seed: "月南風興思"
# 月南風興思，人在須盡顇。催宗暗鴻律，面刀欄袖谷。泛漢訪平仁，辭暫攀令有。歲四秦安物，裳點交雪窮。
# ----- diversity: 1.2
# ----- Generating with seed: "月南風興思"
# 月南風興思，黃存白幾復。生岐弦一易，鮮點維舞縱。孝井規營揖，駿檝宿暗苔。旂夏聊揖謀，翠竭幸父物。
# Epoch 9/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5134
#
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "胡寒螿愛碧"
# 胡寒螿愛碧，歸鳴暮萬里。滿山見枝夕，曲無來柳三。空望深東萬，年何誰望青。天秦更知煙，愁却出殘聲。
# ----- diversity: 0.5
# ----- Generating with seed: "胡寒螿愛碧"
# 胡寒螿愛碧，歸鳴動求土。却流風問江，西珠綠雲氣。侵萬祀金功，成用山溼爲。衣明情珠不，美萬里玉今。
# ----- diversity: 1.0
# ----- Generating with seed: "胡寒螿愛碧"
# 胡寒螿愛碧，金鳴袖誰神。妾飛峰柳眠，陲變岫自檝。胡維騰織則，骨往待奔往。出盈綵斑亭，結泰一速遺。
# ----- diversity: 1.2
# ----- Generating with seed: "胡寒螿愛碧"
# 胡寒螿愛碧，歸鳴斗影禁。昨青弦出引，裝冷度夢呼。茫鉛谷間星，屢堤禮夜裏。杯擁哀束谷，綺融流入蓋。
# Epoch 10/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5104
#
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "乘疲沒早晚"
# 乘疲沒早晚，金候色寒明。月春日暮紫，微花思錦旒。何羣雪天風，重長水東不。可河上離行，人與在城臺。
# ----- diversity: 0.5
# ----- Generating with seed: "乘疲沒早晚"
# 乘疲沒早晚，金候色寒明。月在曲光色，龍分塞矣柔。明金臺暮泣，窗欲斷紅聽。起鳴光遊時，喜聽夏無人。
# ----- diversity: 1.0
# ----- Generating with seed: "乘疲沒早晚"
# 乘疲沒早晚，蹈壁千微耿。叶摧死夕暉，空那助年不。典厚催以表，明乎之軒於。焉信孤塞宜，虜凋金瑤勢。
# ----- diversity: 1.2
# ----- Generating with seed: "乘疲沒早晚"
# 乘疲沒早晚，情化佩腰攀。宵遞氣蛇臨，悅窗按序恥。褭碣志北得，惜律記雷蛇。考各猶溫分，濟仁復襟衆。
# Epoch 11/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5164
#
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: "誰胡蝶忽然"
# 誰胡蝶忽然，滿漢草時相。愁獨行期一，朝玉關山悲。邊邊塵幽愁，還有念此陽。無情自無枝，又歸來西月。
# ----- diversity: 0.5
# ----- Generating with seed: "誰胡蝶忽然"
# 誰胡蝶忽然，滿隴草頭人。征不復歸來，在朝半得不。史君一萬里，不妾盡兩關。樂終年隴頭，上人不在莫。
# ----- diversity: 1.0
# ----- Generating with seed: "誰胡蝶忽然"
# 誰胡蝶忽然，滿桐草稱無。壯還亨紫示，松煌莫種罪。帝羨也他詩，縈功眼繞花。買顏幷疾射，年拜歡樂則。
# ----- diversity: 1.2
# ----- Generating with seed: "誰胡蝶忽然"
# 誰胡蝶忽然，滿戒土讐負。拜巔防覩路，猷藥嗟傳濁。籩唯此唯耆，軒委破曠休。扆啼贊紵厚，忠輪團追馭。
# Epoch 12/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4966
#
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "盡戲魚通晨"
# 盡戲魚通晨，浦初飛一朝。去去迴竹行，公玉邊時天。天天光明聞，秋日欲輕薄。暮衣枝家山，川西漢亦馬。
# ----- diversity: 0.5
# ----- Generating with seed: "盡戲魚通晨"
# 盡戲魚通晨，浦東飛波魄。柳柳市愁花，四生月爭自。有鄉年人來，鄉降胡志在。玉良無終葉，寒葉霜百沙。
# ----- diversity: 1.0
# ----- Generating with seed: "盡戲魚通晨"
# 盡戲魚通晨，浦砂飛旋外。八纖徧澤濟，遶雪全綵稱。梅弄故淚共，衷看未推麥。擁名萬瀾信，賦致寒鄴復。
# ----- diversity: 1.2
# ----- Generating with seed: "盡戲魚通晨"
# 盡戲魚通晨，臥馭而舉祥。雨東運關綺，佩追摧植紫。宮晴土集羣，故乎咽帶岸。觸積智此千，帳旌熒宮岸。
# Epoch 13/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5052
#
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "情情有餘兮"
# 情情有餘兮，行難別風無。斷開愁願高，山山秋夕風。雲思君人孤，上月流慶金。歆九成天玉，變八春兮自。
# ----- diversity: 0.5
# ----- Generating with seed: "情情有餘兮"
# 情情有餘兮，之極願遇樓。浮園雪暫動，花花不重流。水有家家死，厚貞秦家暉。雲朝生五青，佩白臺壇寒。
# ----- diversity: 1.0
# ----- Generating with seed: "情情有餘兮"
# 情情有餘兮，行以存漁珠。劉鴻可思暮，笛載留緯霏。齊斯松雜桃，巖夜姓倚絕。御共要就長，問容書換滅。
# ----- diversity: 1.2
# ----- Generating with seed: "情情有餘兮"
# 情情有餘兮，擁滄伯就原。口驕風岡雜，帳風市襟空。止珍昇鳳過，燭夜素鬟忒。約四劇威瑟，影買爲煙籠。
# Epoch 14/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5044
#
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "凜嚴霜節冰"
# 凜嚴霜節冰，萬黃雲愁曲。不見不可金，何人成鳳上。新不足春楊，君花生誰朝。日暮日空家，傾城白重雲。
# ----- diversity: 0.5
# ----- Generating with seed: "凜嚴霜節冰"
# 凜嚴霜節冰，馬黃塵中關。地將可不可，昨酒能雙格。雨意深關瑤，離思別水多。多波獨有臥，長草聞在食。
# ----- diversity: 1.0
# ----- Generating with seed: "凜嚴霜節冰"
# 凜嚴霜節冰，復黃泉故徑。悄事烽貺寶，青屋浮水通。舍烽嚴寸破，貌旗侍縣隴。律厥蹈秋芳，莖調笙變更。
# ----- diversity: 1.2
# ----- Generating with seed: "凜嚴霜節冰"
# 凜嚴霜節冰，識雅驕逸璧。而咽往載點，秦當棘可刺。建鞭環殺和，中宮負賢奔。遵踐楚泣持，胡入昇寥宜。
# Epoch 15/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5091
#
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: "泰山之下婦"
# 泰山之下婦，誰哭奏容雲。明祀初思時，萬日綠雲哀。行行河長城，日稀昏劒日。風來歸馬不，可憐今昔長。
# ----- diversity: 0.5
# ----- Generating with seed: "泰山之下婦"
# 泰山之下婦，誰哭奏哭將。同晨歸人心，妾揚故感處。同妾有情香，明扇御聞照。圖我婦爲人，相爲人朝雲。
# ----- diversity: 1.0
# ----- Generating with seed: "泰山之下婦"
# 泰山之下婦，手哭舊他鄉。高面將調顧，先遂媿暫繡。作都采紫爐，棄餘列鐘旅。雍雍廣敬賜，辭家聊運高。
# ----- diversity: 1.2
# ----- Generating with seed: "泰山之下婦"
# 泰山之下婦，直掌光鬼承。誠片至臨遵，月京擣備此。鱗神酣單煌，近取旌浮州。敢鴻旦圖充，十憑冬貽披。
# Epoch 16/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4930
#
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "到市橋步野"
# 到市橋步野，相見相如稀。曲遊樂不能，新未央宮入。愁願因中雲，今樂敢歡宴。芳懷白露高，舊樓神其止。
# ----- diversity: 0.5
# ----- Generating with seed: "到市橋步野"
# 到市橋步野，消衛去遊宮。柏中前然弦，無生人一軍。杯且胡爲行，國陰軍起太。虜星風生得，舞庭霜前安。
# ----- diversity: 1.0
# ----- Generating with seed: "到市橋步野"
# 到市橋步野，能咸比惟憐。破驚啼有但，殺臺哉鬯穹。軍反別綵咽，泣虔恤誠歡。沒翁願船霑，路爲根殊蘭。
# ----- diversity: 1.2
# ----- Generating with seed: "到市橋步野"
# 到市橋步野，穿鞭蓋君波。形廣羌終雲，躬養羌松魂。龍降窗嚬奏，寒總簾化烈。嬌喧測朔縈，四化躬鶯鴛。
# Epoch 17/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5123
#
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "穴戍衣宵寢"
# 穴戍衣宵寢，二聲食符獻。一冠荷中方，被月寒明光。戈動秋時悲，花爲人不別。不得意妾相，思君不忘王。
# ----- diversity: 0.5
# ----- Generating with seed: "穴戍衣宵寢"
# 穴戍衣宵寢，二八食老聲。樂文敢賤在，空望裏裏如。在何處與妾，桑流衣應明。德上雍熙兮，將兄可見歸。
# ----- diversity: 1.0
# ----- Generating with seed: "穴戍衣宵寢"
# 穴戍衣宵寢，二征瞿樹儀。冠干飛木言，鄰意意少賤。不相延先房，宇詎寵放規。離暇去應何，疑用旄殷窺。
# ----- diversity: 1.2
# ----- Generating with seed: "穴戍衣宵寢"
# 穴戍衣宵寢，二都醉州窟。關山夏順隔，憂劇自疎風。屬戈急臣露，簾花紀倡家。婦養承富帝，子深惠君不。
# Epoch 18/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4951
#
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "山林岸曲非"
# 山林岸曲非，還君莫沙感。神光相居歸，來燕山雪作。大山傷出身，不吟鳳上來。山流平向縈，中空散采天。
# ----- diversity: 0.5
# ----- Generating with seed: "山林岸曲非"
# 山林岸曲非，獨妾未聞道。難重別高聲，風流入獻初。月起裏花不，乾龍方安吹。歸天外人明，愁欲斷玉行。
# ----- diversity: 1.0
# ----- Generating with seed: "山林岸曲非"
# 山林岸曲非，還憶馬煙長。烏違棲禮樂，展負鞭燒駿。臨侵利問遐，席分勞皇鏡。浮妍吾聞履，被溫劒影範。
# ----- diversity: 1.2
# ----- Generating with seed: "山林岸曲非"
# 山林岸曲非，源泰洞辰是。桃冥橋昭谷，神裝揚延強。稷搖文名拜，錯袖茫叢禁。集盈雝植危，好白終露用。
# Epoch 19/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5147
#
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "期歷試佐貳"
# 期歷試佐貳，傳立融恨知。聽容曲不絕，容易貌安聞。道人別離別，人地不歸入。侯南中說處，流落風池色。
# ----- diversity: 0.5
# ----- Generating with seed: "期歷試佐貳"
# 期歷試佐貳，傳輕曲方長。門東白去中，馬歎黃金不。惜虛上心雲，泣無人不來。酒不人年旦，南復映胡爲。
# ----- diversity: 1.0
# ----- Generating with seed: "期歷試佐貳"
# 期歷試佐貳，著豈隨妝罄。卿貌遲察衣，類繼土攀濃。仰皓凍扆朝，便瑞花眼莫。追征人驚散，斷鴻魂作商。
# ----- diversity: 1.2
# ----- Generating with seed: "期歷試佐貳"
# 期歷試佐貳，寄絡恣希息。織交理未終，吾役聊悵履。巧淒五繫月，片幾堤柳摘。肌迥讓豪閉，煙宛遼亂辰。
# Epoch 20/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4970
#
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "入漢宮富貴"
# 入漢宮富貴，可開久人上。不得一朝此，青歌時萬長。能哀哀一爲，獵金人著妾。草在爲爲君，顏將羞胡白。
# ----- diversity: 0.5
# ----- Generating with seed: "入漢宮富貴"
# 入漢宮富貴，可對久里爲。長多待聞有，情馬東浪爾。動移白駐菊，叢叢叢圍月。斷絕封猶惟，煙空生一世。
# ----- diversity: 1.0
# ----- Generating with seed: "入漢宮富貴"
# 入漢宮富貴，可吾勒希奇。河采片輕春，萬父管冷成。玉舟移均言，而同小無渭。脫基皓昨洲，流洽首命出。
# ----- diversity: 1.2
# ----- Generating with seed: "入漢宮富貴"
# 入漢宮富貴，可草饗馬率。良自揚瓊唐，如今庭命座。疎兔蓬高笛，斜匣參雍陌。他跡燈條二，染設及異縫。
# Epoch 21/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4965
#
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "肅雝孝享祚"
# 肅雝孝享祚，我斷絕終無。人上下長門，道世無還有。自古各平西，日猶新愁大。荒何處宿有，雪轉舞玉春。
# ----- diversity: 0.5
# ----- Generating with seed: "肅雝孝享祚"
# 肅雝孝享祚，我葉朝長遶。珠鳳不作明，天地路入中。遮翼往舊收，輝流隨序明。方動敬懷迎，神心在銷覺。
# ----- diversity: 1.0
# ----- Generating with seed: "肅雝孝享祚"
# 肅雝孝享祚，我哭暫申鏘。初山依荒人，牀枝砂昏沒。人條豔地甘，旗調飜詞露。碣籥墜次土，簾袖負淚多。
# ----- diversity: 1.2
# ----- Generating with seed: "肅雝孝享祚"
# 肅雝孝享祚，我似夜只廊。誰鴻桐匣縱，稀覺臻衆方。送往峨楊轍，遐沖送陰征。女必噴遲宴，奕布庶以反。
# Epoch 22/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4980
#
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "深玉白蘭芳"
# 深玉白蘭芳，葉相欲百年。始生得得意，身愁定人不。得不見至愁，何更有樓四。時枝方風一，生翡東樹一。
# ----- diversity: 0.5
# ----- Generating with seed: "深玉白蘭芳"
# 深玉白蘭芳，葉各夷萬靈。玉爭不似良，愁見生君別。別離多相張，玉行歲歲物。天延漁回戎，階寶幾聲和。
# ----- diversity: 1.0
# ----- Generating with seed: "深玉白蘭芳"
# 深玉白蘭芳，佐放夢君唯。入陰受軒豈，合竟楊樹風。來舞魚箭殺，翡余皎區花。中腸凝史衛，階結珠簋觴。
# ----- diversity: 1.2
# ----- Generating with seed: "深玉白蘭芳"
# 深玉白蘭芳，葉積羞角遺。郊風璫瑞愛，乾夫顏賞枕。方常繫著駕，絳缺仰羣煙。錫圓伯寧宇，廟骨塵土觴。
# Epoch 23/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4985
#
# ----- Generating text after Epoch: 22
# ----- diversity: 0.2
# ----- Generating with seed: "扇自知秋風"
# 扇自知秋風，條寂無寂寂。寥十寂碧髮，問隱調新千。金鞍成一時，白日鳳光漸。大悲夜長晝，爲聲和日見。
# ----- diversity: 0.5
# ----- Generating with seed: "扇自知秋風"
# 扇自知秋風，琴始空是雲。邊行一德天，小塞南海長。城家何忽如，此萬難重君。風彈花餘銅，暫向共寥終。
# ----- diversity: 1.0
# ----- Generating with seed: "扇自知秋風"
# 扇自知秋風，空綴破黃鶯。尾陳棗濃先，堯小良盛累。輝穆朝歸梁，雲迴落仙極。來粉衛紅楚，地人尋躍吹。
# ----- diversity: 1.2
# ----- Generating with seed: "扇自知秋風"
# 扇自知秋風，足翰和調疑。未錯江忽授，抱仁賢目螻。者總任雷塵，二通圍盤劒。文國行移鷹，腸牲讓前羞。
# Epoch 24/30
# 45572/45572 [==============================] - 6s 132us/step - loss: 1.5015
#
# ----- Generating text after Epoch: 23
# ----- diversity: 0.2
# ----- Generating with seed: "鴦調砧亂杵"
# 鴦調砧亂杵，殘自若紅青。雲宮來春宮，門樹色意非。爲且紫安共，從南風吹長。不可留行路，飄飄空雲成。
# ----- diversity: 0.5
# ----- Generating with seed: "鴦調砧亂杵"
# 鴦調砧亂杵，鈞自不逐象。日纖爲君秋，空飛白妾原。立白日黃有，君王孫君千。年珠被不行，停樂章文章。
# ----- diversity: 1.0
# ----- Generating with seed: "鴦調砧亂杵"
# 鴦調砧亂杵，辛余對淺金。陽拳鴈殊眇，與九飄虜雖。夷久郎席珍，懸肉旅涵勢。行鴻字胄低，朝鷹順堆參。
# ----- diversity: 1.2
# ----- Generating with seed: "鴦調砧亂杵"
# 鴦調砧亂杵，臂自開馨謁。斬羽耳嚴梢，今抱已禁舒。淺衢海器獵，資草躕長壇。世曠堆暮亙，賢持顦二氣。
# Epoch 25/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4914
#
# ----- Generating text after Epoch: 24
# ----- diversity: 0.2
# ----- Generating with seed: "何嗟及我昔"
# 何嗟及我昔，初石傳出初。頭花花開自，知一年無看。來不相見逐，君一誰能事。半望龍欲欲，下不得天下。
# ----- diversity: 0.5
# ----- Generating with seed: "何嗟及我昔"
# 何嗟及我昔，初貪傳秋江。因風顧鼓棄，顧桂恨地田。覺洞芳沈青，飛分欲上輕。列從關山路，難遠行路行。
# ----- diversity: 1.0
# ----- Generating with seed: "何嗟及我昔"
# 何嗟及我昔，初花興河今。木音陪祚津，所灰無鄉言。箏同眷九方，鳳曲鯨却合。簾成輸玉平，茲嶽雨馳斬。
# ----- diversity: 1.2
# ----- Generating with seed: "何嗟及我昔"
# 何嗟及我昔，初晨光比當。空閑堪延岐，白蛇嚴掌朝。邊木暮者奇，如基撫右若。如中約霜斗，情樽帳陽樹。
# Epoch 26/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4901
#
# ----- Generating text after Epoch: 25
# ----- diversity: 0.2
# ----- Generating with seed: "翻傷掩鮑車"
# 翻傷掩鮑車，車輪輪來人。地從來不見，人來鳥臺上。人間如永永，懷留窮城南。有回馬前春，日江南千萬。
# ----- diversity: 0.5
# ----- Generating with seed: "翻傷掩鮑車"
# 翻傷掩鮑車，車輪開仰珠。青大輕去年，結朝野作山。綺陣山漢家，靜南還稀綠。崇君心芳菲，玉長信舊騎。
# ----- diversity: 1.0
# ----- Generating with seed: "翻傷掩鮑車"
# 翻傷掩鮑車，斬固芬蕭毛。宣脫辭雖秩，琴地舞近倚。承沙尚替寄，同戶德北細。條人放梨酒，穹衣夢女良。
# ----- diversity: 1.2
# ----- Generating with seed: "翻傷掩鮑車"
# 翻傷掩鮑車，尉祥奴瀾疎。種葉隅澀波，生得人誰家。靜椒晚芳牀，口潭因牲祗。今奇含驚從，四漢應不疆。
# Epoch 27/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4946
#
# ----- Generating text after Epoch: 26
# ----- diversity: 0.2
# ----- Generating with seed: "如笙碎在緱"
# 如笙碎在緱，日更低山頭。樹空去歸無，窮日暮空空。星紫天地誰，家親處顏花。蒼蒼迎朝朝，朝至顏暮煙。
# ----- diversity: 0.5
# ----- Generating with seed: "如笙碎在緱"
# 如笙碎在緱，更更憐連樹。魚絲水雪何，處流水盡關。門聲淥無定，渡紅驚生黃。別一悲長空，不能東南飛。
# ----- diversity: 1.0
# ----- Generating with seed: "如笙碎在緱"
# 如笙碎在緱，理更遺參新。玉服白濃邙，映祇途旦鄉。忽易李行萬，迥虹瑟清暢。層嘗賢搖獨，沙多聽豐雪。
# ----- diversity: 1.2
# ----- Generating with seed: "如笙碎在緱"
# 如笙碎在緱，消當津壯集。面却我運坤，文固層寢玉。生討粹上氛，唱相婦豈昔。燕易度學故，那砧箭殿昔。
# Epoch 28/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4924
#
# ----- Generating text after Epoch: 27
# ----- diversity: 0.2
# ----- Generating with seed: "幸他人之既"
# 幸他人之既，不我先惟人。絕妾德何處，燕然有門前。蛾眉淚愁不，飲不可顧情。一隨生得子，悲未行有身。
# ----- diversity: 0.5
# ----- Generating with seed: "幸他人之既"
# 幸他人之既，不我先已春。月歌流霜夕，霞水短歌令。和不終高胡，還人行漢宮。相思恨別有，何處飄鳳不。
# ----- diversity: 1.0
# ----- Generating with seed: "幸他人之既"
# 幸他人之既，不我先裔阿。羣波絡前戰，守同雁膺蕙。虔再看曠正，五蛇顦病笳。俟弄帷爭待，束手室持閑。
# ----- diversity: 1.2
# ----- Generating with seed: "幸他人之既"
# 幸他人之既，不平先瓦劫。賢熊屍洞狼，萬能宛醉薄。虜未卒彌悲，瞻把乃辭劒。魚肯迷舊頭，己草佐謝橋。
# Epoch 29/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.4911
#
# ----- Generating text after Epoch: 28
# ----- diversity: 0.2
# ----- Generating with seed: "生荆棘誰道"
# 生荆棘誰道，黃金如落白。風水中風陵，節長同平朔。朔風日客光，使君風東海。西遊不西見，嬌春日欲輕。
# ----- diversity: 0.5
# ----- Generating with seed: "生荆棘誰道"
# 生荆棘誰道，黃處如落雲。落高酒北春，草上後春與。主不移明所，欲歎愁從東。不成玉俗爲，我歡光徒服。
# ----- diversity: 1.0
# ----- Generating with seed: "生荆棘誰道"
# 生荆棘誰道，黃過如潛偏。白惡朝屋駕，衆止湖赫都。海觴廣當蜀，綠女廣坐豈。請舍碧霧五，第暖年魚從。
# ----- diversity: 1.2
# ----- Generating with seed: "生荆棘誰道"
# 生荆棘誰道，黃電冕飛處。武扇廢畫少，雙當象如林。虎帶求婦徒，作畢叶晝爲。是魚更漏濤，平晉誓著壓。
# Epoch 30/30
# 45572/45572 [==============================] - 6s 133us/step - loss: 1.5021
#
# ----- Generating text after Epoch: 29
# ----- diversity: 0.2
# ----- Generating with seed: "千重碎迎風"
# 千重碎迎風，一香流君不。再關轉朝山，山溼處淚淚。不可憐可憐，上客心乎鳳。上月同君太，陽流遊妾莫。
# ----- diversity: 0.5
# ----- Generating with seed: "千重碎迎風"
# 千重碎迎風，一香流越亂。處相臺飛雲，共芳上暗已。通愁垂可憐，河曲悲正淒。亭報君家都，萬國往望不。
# ----- diversity: 1.0
# ----- Generating with seed: "千重碎迎風"
# 千重碎迎風，一荷事小鉤。舟芙蓉長冷，芳搖漢八點。四二吳芳時，拂姑袖森無。蠁指應曾神，覆徵皎鱗風。
# ----- diversity: 1.2
# ----- Generating with seed: "千重碎迎風"
# 千重碎迎風，一香殿史因。豪懷麗烈裴，肉旅勝蕃銀。則垂辰分高，永疊鏘村至。存徹夜斾空，虜裝洽強澹。

# %%
# 根據一個字產生詩
def predict_first(char, diversity=1):
        
        # sentence = 隨機選一段長度為4的句子放在前面
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated = ''
        result = ''
        count = 1
        sentence = text[start_index: start_index + maxlen - 1]
        sentence += char
        generated += sentence
        print('開始文字：', char)
        result += char
        
        for i in range(1,40):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]
            
            if count%10 == 0:
                result += "。\n"
            elif count%5 == 0:
                result += "，"
            generated += next_char
            sentence = sentence[1:] + next_char

            result += next_char
            count += 1
        result += "。"
        
        return result

# %%
#藏頭詩
def predict_hide(line, diversity=1):
    
        # sentence = 隨機選一段長度為4的句子放在前面
        start_index = random.randint(0, len(text) - maxlen - 1)
        generated = ''
        result = ''
        count = 1
        sentence = text[start_index: start_index + maxlen - 1]
        sentence += line[0]
        generated += sentence
        print('藏頭句子：', line)
        result += line[0]
        
        for i in range(1,40):
            if count%10 == 0:
                result += "。\n"
            elif count%5 == 0:
                result += "，"
            
            # 加入藏頭的文字
            if count%10 == 0:
                generated += line[count//10]
                sentence = sentence[1:] + line[count//10]
                result += line[count//10]
                count += 1
                continue
                
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            result += next_char
            count += 1
        result += "。"
        
        return result

# %%
# 根據字首產生五言律詩
sen = predict_first('風')
print(sen)
# Out:
# 開始文字： 風
# 風且送和耀，潔芙霞期行。
# 絳候有網揚，巧綠腰衛惜。
# 迎贈宮木濤，資血七凝颯。
# 均碣霜鬢酒，罄激楹豫當。

# %%
#藏頭詩，可藏四個字
sen = predict_hide('山窮水盡')
print(sen)
# Out:
# 藏頭句子： 山窮水盡
# 山窗闈留滴，厥常罷棄商。
# 窮羽邁河賤，獻聊立況郎。
# 水馨北鳳早，分苔悲爭麗。
# 盡景運魚裝，兒泰直守三。
